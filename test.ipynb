# %%
import pandas as pd

# %%
data = pd.read_csv("data/murid/Murid.csv")

# %%
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                           Nama Lengkap;Mata kuliah yang ingin kamu pelajari;Topik atau sub-bab spesifik yang ingin kamu bahas;Tujuan utama belajar Kamu;Hari   \
# ...
